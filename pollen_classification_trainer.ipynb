# %%
# %%capture
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/pollen_classification/code

# %%
from pollen_classification import Param, train, test
test(Param)
# Out:
#   Test metrics for ResNet3D_1e-6:
#
#                 loss      --->     0.4443475604057312
#
#                 f1 score  --->     0.7881778671510119
#
#                 accuracy  --->     0.8
